# %%
API_key = '039163dca0msh7ecfddf47a57b42p193f39jsn80c27500a5c2'

url = "https://moviesdatabase.p.rapidapi.com/titles"

querystring = {"startYear":"2010","endYear":"2011","limit":"50"} # limite 50

headers = {
	"X-RapidAPI-Key": API_key,
	"X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
print(type(response.json()))
print(response.json())

next = response.json()['next']


while len(next)!=0:
    url_next = f"https://moviesdatabase.p.rapidapi.com{(next)}/"
    print(url_next)
    response = requests.get(url_next, headers=headers, params=querystring)
    print(type(response.json()))
    print(response.json())
    next = response.json()['next']
# Out:
# <class 'dict'>
# {'page': 1, 'next': '/titles?endYear=2011&limit=50&startYear=2010&page=2', 'entries': 50, 'results': [{'_id': '61e582368a5a6a599f418ebb', 'id': 'tt0176694', 'primaryImage': {'id': 'rm3068795392', 'width': 400, 'height': 571, 'url': 'https://m.media-amazon.com/images/M/MV5BMTEwODljN2MtNjNhNC00NGIwLTk3YjgtODA5MzIzYjZiYWMwXkEyXkFqcGdeQXVyNTczMzEzMDY@._V1_.jpg', 'caption': {'plainText': 'Az ember tragédiája (2011)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Az ember tragédiája', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Az ember tragédiája', '__typename': 'TitleText'}, 'releaseYear': {'year': 2011, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 8, 'month': 12, 'year': 2011, '__typename': 'ReleaseDate'}}, {'_id': '61e58256cffb8f2faa4195ab', 'id': 'tt0187902', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': "How Huang Fei-hong Rescued the Orphan from the Tiger's Den", '__typename': 'TitleText'}, 'originalTitleText': {'text': "How Huang Fei-hong Rescued the Orphan from the Tiger's Den", '__typename': 'TitleText'}, 'releaseYear': {'year': 2011, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2011, '__typename': 'ReleaseDate'}}, {'_id': '61e58291a66e59642341a2e9', 'id': 'tt0209969', 'primaryImage': None, 'titleType': {'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Cimetière dans la falaise', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Cimetière dans la falaise', '__typename': 'TitleText'}, 'releaseYear': {'year': 2011, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 9, 'month': 1, 'year': 2011, '__typename': 'ReleaseDate'}}, {'_id': '61e58291b597b91eb941a34f', 'id': 'tt0210470', 'primaryImage': {'id': 'rm3748156160', 'width': 600, 'height': 450, 'url': 'https://m.media-amazon.com/images/M/MV5BZjcxY2E4MDUtZTI3MC00MWRmLWE3NDgtYjc2ZGM2ZjNkY2IzXkEyXkFqcGdeQXVyMjYxMzY2NDk@._V1_.jpg', 'caption': {'plainText': '50 Feet of String (2011)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': '50 Feet of String', '__typename': 'TitleText'}, 'originalTitleText': {'text': '50 Feet of String', '__typename': 'TitleText'}, 'releaseYear': {'year': 2011, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 1995, '__typename': 'ReleaseDate'}}, {'_id': '61e582f678c012aa3441b943', 'id': 'tt0247643', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Los pájaros se van con la muerte', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Los pájaros se van con la muerte', '__typename': 'TitleText'}, 'releaseYear': {'year': 2011, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 6, 'month': 6, 'year': 2011, '__typename': 'ReleaseDate'}}, {'_id': '61e5831e95801a78bc41c38b', 'id': 'tt0262463', 'primaryImage': None, 'titleType': {'text': 'TV Episode', 'id': 'tvEpisode', 'isSeries': False, 'isEpisode': True, '__typename': 'TitleType'}, 'titleText': {'text': 'Mit doppeltem Boden', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Mit doppeltem Boden', '__typename': 'TitleText'}, 'releaseYear': {'year': 2011, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2011, '__typename': 'ReleaseDate'}}, {'_id': '61e5834aef99b1c54341cc7b', 'id': 'tt0277784', 'primaryImage': {'id': 'rm1171202304', 'width': 1574, 'height': 1032, 'url': 'https://m.media-amazon.com/images/M/MV5B ...
# https://moviesdatabase.p.rapidapi.com/titles?endYear=2011&limit=50&startYear=2010&page=2/
# <class 'dict'>
# {'error': 'Limit parameter error, limit has to be a number between 1 an 51', 'stack': '🥞', 'results': None}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_490/2911145355.py in <module>
#      25     print(type(response.json()))
#      26     print(response.json())
# ---> 27     next = response.json()['next']
#      28
#
# KeyError: 'next'

# %%
url = "https://moviesdatabase.p.rapidapi.com/titles/tt10061702"

headers = {
	"X-RapidAPI-Key": "039163dca0msh7ecfddf47a57b42p193f39jsn80c27500a5c2",
	"X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'results': {'_id': '61e58b8aa66e59642343ac3f', 'id': 'tt10061702', 'primaryImage': {'id': 'rm13190401', 'width': 2048, 'height': 2732, 'url': 'https://m.media-amazon.com/images/M/MV5BMjljOTM5YzEtYjQ1Yy00NjQzLWE4YjgtZGQwMDFkNGRiZjRmXkEyXkFqcGdeQXVyMTkzMTgzMTU@._V1_.jpg', 'caption': {'plainText': "We're Alive: Scout's Honor (2024)", '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': 'TV Mini Series', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'TV Mini Series', 'id': 'tvMiniSeries', 'isSeries': True, 'isEpisode': False, 'categories': [{'value': 'tv', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': True, '__typename': 'TitleType'}, 'titleText': {'text': "We're Alive: Scout's Honor", '__typename': 'TitleText'}, 'originalTitleText': {'text': "We're Alive: Scout's Honor", '__typename': 'TitleText'}, 'releaseYear': {'year': 2024, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 19, 'month': 3, 'year': 2024, '__typename': 'ReleaseDate'}}}

# %%
API_key = '039163dca0msh7ecfddf47a57b42p193f39jsn80c27500a5c2'

url = "https://moviesdatabase.p.rapidapi.com/titles"

querystring = {"genre":"Drama","year":"2010","limit":"50"} # limite 50 #50 primeros drama 2010

headers = {
	"X-RapidAPI-Key": API_key,
	"X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

next = response.json()['next']

response_json = response.json()
response_json.keys()

lista_cincuenta_pelicula_drama = []

for result in response_json['results']:
    print(result['id'])
    print(result['titleType']['id'])
    print(result['titleText']['text'])
    print(result)
# Out:
# tt0146592
# movie
# Pál Adrienn
# {'_id': '61e581e3b597b91eb9417cbb', 'id': 'tt0146592', 'primaryImage': {'id': 'rm437535488', 'width': 1020, 'height': 1464, 'url': 'https://m.media-amazon.com/images/M/MV5BODNjZmM3MWYtYmUwZC00M2RjLTkyZmEtYzRhMDU1NmM3ZmIzXkEyXkFqcGdeQXVyOTAzODAwOQ@@._V1_.jpg', 'caption': {'plainText': 'Pál Adrienn (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Pál Adrienn', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Pál Adrienn', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 2, 'month': 6, 'year': 2011, '__typename': 'ReleaseDate'}}
# tt0154039
# movie
# Oda az igazság
# {'_id': '61e581f3e1a8ddbd96418015', 'id': 'tt0154039', 'primaryImage': {'id': 'rm3848681984', 'width': 400, 'height': 590, 'url': 'https://m.media-amazon.com/images/M/MV5BM2U4NWIxMjQtZTE4ZC00MThmLTlmMTktMWM3OTQ3ODc1ZmI4L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjIzMDAwOTc@._V1_.jpg', 'caption': {'plainText': 'Oda az igazság (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Oda az igazság', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Oda az igazság', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 11, 'month': 2, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0162942
# movie
# A zöld sárkány gyermekei
# {'_id': '61e5821178c012aa3441860f', 'id': 'tt0162942', 'primaryImage': {'id': 'rm2630750720', 'width': 1013, 'height': 1456, 'url': 'https://m.media-amazon.com/images/M/MV5BNDhkMTJkNTYtMTYwZS00NTYwLTgzZGYtMTlmYWE3MWM1NGVhXkEyXkFqcGdeQXVyNzM0MDQ1Mw@@._V1_.jpg', 'caption': {'plainText': 'A zöld sárkány gyermekei (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'A zöld sárkány gyermekei', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'A zöld sárkány gyermekei', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 7, 'month': 4, 'year': 2011, '__typename': 'ReleaseDate'}}
# tt0200641
# video
# Flexing with Monty
# {'_id': '61e5827c78c012aa34419db3', 'id': 'tt0200641', 'primaryImage': {'id': 'rm1353682432', 'width': 508, 'height': 722, 'url': 'https://m.media-amazon.com/images/M/MV5BMTY4MTE2MTQyNF5BMl5BanBnXkFtZTcwMTA4MDk5Mg@@._V1_.jpg', 'caption': {'plainText': 'Flexing with Monty (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Video', 'id': 'video', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Flexing with Monty', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Flexing with Monty', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 7, 'month': 1, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0230212
# movie
# The Final Journey
# {'_id': '61e582c98a5a6a599f41afcb', 'id': 'tt0230212', 'primaryImage': {'id': 'rm3010560256', 'width': 1456, 'height': 2048, 'url': 'https://m.media-amazon.com/images/M/MV5BNDY0NDMwNjg5Ml5BMl5BanBnXkFtZTcwOTU0NTc4Mw@@._V1_.jpg', 'caption': {'plainText': 'The Final Journey (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'The Final Journey', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'The Final Journey', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 20, 'month': 9, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0326965
# movie
# In My Sleep
# {'_id': '61e583cd909c2ca78141e9ff', 'id': 'tt0326965', 'primaryImage': {'id': 'rm1659801600', 'width': 450, 'height': 669, 'url': 'https://m.media-amazon.com/images/M/MV5BNzg1MDM1NzIwMV5BMl5BanBnXkFtZTcwNzMxMTU1MQ@@._V1_.jpg', 'caption': {'plainText': 'In My Sleep (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'In My Sleep', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'In My Sleep', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 23, 'month': 4, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0331312
# movie
# This Wretched Life
# {'_id': '61e583d9971a4a15d641ed6f', 'id': 'tt0331312', 'primaryImage': {'id': 'rm2856504064', 'width': 1575, 'height': 2250, 'url': 'https://m.media-amazon.com/images/M/MV5BMTU3ODgxNjE4M15BMl5BanBnXkFtZTgwMTEyNjY0MTE@._V1_.jpg', 'caption': {'plainText': 'This Wretched Life (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'This Wretched Life', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'This Wretched Life', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 28, 'month': 7, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0337882
# movie
# Blind Sided
# {'_id': '61e583f178c012aa3441f209', 'id': 'tt0337882', 'primaryImage': {'id': 'rm1023643392', 'width': 1547, 'height': 2174, 'url': 'https://m.media-amazon.com/images/M/MV5BMTY3NjQxMzAyOF5BMl5BanBnXkFtZTcwMjcyNTMyMw@@._V1_.jpg', 'caption': {'plainText': 'Blind Sided (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Blind Sided', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Blind Sided', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': None}
# tt0370451
# short
# Death of a Nation
# {'_id': '61e58449cffb8f2faa420703', 'id': 'tt0370451', 'primaryImage': {'id': 'rm2870648064', 'width': 450, 'height': 675, 'url': 'https://m.media-amazon.com/images/M/MV5BMTgzMTAwNDkzOF5BMl5BanBnXkFtZTcwODc3ODUzMQ@@._V1_.jpg', 'caption': {'plainText': 'Death of a Nation (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Death of a Nation', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Death of a Nation', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 28, 'month': 6, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0374463
# tvMiniSeries
# The Pacific
# {'_id': '61e58452ef99b1c543420957', 'id': 'tt0374463', 'primaryImage': {'id': 'rm2679978240', 'width': 2109, 'height': 3105, 'url': 'https://m.media-amazon.com/images/M/MV5BNmEwNmI1MjItNjNjYy00NDE5LWJiNTYtM2QxMTI5ZjllZTBhL2ltYWdlXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_.jpg', 'caption': {'plainText': 'The Pacific (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'TV Mini Series', 'id': 'tvMiniSeries', 'isSeries': True, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'The Pacific', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'The Pacific', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': 2010, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': 4, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0378927
# short
# Turning It Over
# {'_id': '61e5845e78c012aa34420bbf', 'id': 'tt0378927', 'primaryImage': {'id': 'rm2181793793', 'width': 1242, 'height': 1957, 'url': 'https://m.media-amazon.com/images/M/MV5BZDYyZDI3ZDQtOWZkYy00MjlkLWE2MWItYzY3NmJiNGYyYTAyXkEyXkFqcGdeQXVyMDQyODI1MQ@@._V1_.jpg', 'caption': {'plainText': 'Turning It Over (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Turning It Over', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Turning It Over', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': None}
# tt0393049
# movie
# Anderson's Cross
# {'_id': '61e58485d8f3c0931e4215c5', 'id': 'tt0393049', 'primaryImage': {'id': 'rm679077376', 'width': 627, 'height': 947, 'url': 'https://m.media-amazon.com/images/M/MV5BOTcwOTIyNTEzMF5BMl5BanBnXkFtZTgwMDE0MTM2NzE@._V1_.jpg', 'caption': {'plainText': "Heather Bergdahl, Nicholas Downs, Jerome Elston Scott, and Micah Stuart in Anderson's Cross (2010)", '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': "Anderson's Cross", '__typename': 'TitleText'}, 'originalTitleText': {'text': "Anderson's Cross", '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 20, 'month': 5, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0396123
# movie
# Den milde smerte
# {'_id': '61e5848fa66e596423421781', 'id': 'tt0396123', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Den milde smerte', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Den milde smerte', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 14, 'month': 5, 'year': 2014, '__typename': 'ReleaseDate'}}
# tt0402887
# movie
# Capture the Flag
# {'_id': '61e584a1d735dff3f9421bf7', 'id': 'tt0402887', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Capture the Flag', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Capture the Flag', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': None}
# tt0403645
# movie
# Utomlennye solntsem 2
# {'_id': '61e584a5a66e596423421ca5', 'id': 'tt0403645', 'primaryImage': {'id': 'rm2220239616', 'width': 1660, 'height': 2362, 'url': 'https://m.media-amazon.com/images/M/MV5BYmJhNWMwMWUtZWJiNS00ZjJmLThiMDktMzYxYzJkNmY2YzE5XkEyXkFqcGdeQXVyNjMwOTA1MDM@._V1_.jpg', 'caption': {'plainText': 'Nikita Mikhalkov in Utomlennye solntsem 2 (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Utomlennye solntsem 2', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Utomlennye solntsem 2', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 22, 'month': 4, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0411951
# movie
# Tekken
# {'_id': '61e584b7971a4a15d64220ed', 'id': 'tt0411951', 'primaryImage': {'id': 'rm1678965761', 'width': 800, 'height': 1181, 'url': 'https://m.media-amazon.com/images/M/MV5BODQ3YTBmYzYtZjU2MS00YmRmLTk2ZmYtZDgwNmYxODYxNzEyXkEyXkFqcGdeQXVyNjQ2MjQ4MzQ@._V1_.jpg', 'caption': {'plainText': 'Tekken (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Tekken', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Tekken', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 20, 'month': 3, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0419692
# movie
# Disconnect
# {'_id': '61e584d078c012aa3442256b', 'id': 'tt0419692', 'primaryImage': {'id': 'rm2327296512', 'width': 314, 'height': 470, 'url': 'https://m.media-amazon.com/images/M/MV5BMTc0NzM4NTQ5Nl5BMl5BanBnXkFtZTcwMjI3NTY0NA@@._V1_.jpg', 'caption': {'plainText': 'Disconnect (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Disconnect', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Disconnect', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': 8, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0443331
# movie
# Milenge Milenge
# {'_id': '61e58511a66e5964234234f5', 'id': 'tt0443331', 'primaryImage': {'id': 'rm3573645568', 'width': 346, 'height': 500, 'url': 'https://m.media-amazon.com/images/M/MV5BNDU2MjM5NzAzMl5BMl5BanBnXkFtZTcwNzM2MjE5Mw@@._V1_.jpg', 'caption': {'plainText': 'Milenge Milenge (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Milenge Milenge', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Milenge Milenge', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 9, 'month': 7, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0445054
# movie
# Les 7 jours du talion
# {'_id': '61e58511e1a8ddbd96423497', 'id': 'tt0445054', 'primaryImage': {'id': 'rm199694592', 'width': 520, 'height': 750, 'url': 'https://m.media-amazon.com/images/M/MV5BYmNkMWFiZGMtYzU4Yi00ZjJiLWI1YmYtMWIwZjBjMWY0OTY0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg', 'caption': {'plainText': 'Les 7 jours du talion (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Les 7 jours du talion', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Les 7 jours du talion', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 12, 'month': 11, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0444531
# movie
# Vidas pequeñas
# {'_id': '61e5851378c012aa344234c1', 'id': 'tt0444531', 'primaryImage': {'id': 'rm2232752128', 'width': 1024, 'height': 1455, 'url': 'https://m.media-amazon.com/images/M/MV5BYTViMzUyMTUtMjY2NC00ZDU2LTk2NDMtMjBkYTQwNGE1Nzc3XkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_.jpg', 'caption': {'plainText': 'Asunción Balaguer, Francisco Boira, Alicia Borrachero, Yohana Cobo, Roberto Enríquez, Ana Fernández, Emilio Gutiérrez Caba, Ángela Molina, and Pepo Oliva in Vidas pequeñas (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Vidas pequeñas', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Vidas pequeñas', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 18, 'month': 3, 'year': 2011, '__typename': 'ReleaseDate'}}
# tt0446686
# movie
# Dream Street
# {'_id': '61e5851695801a78bc4236ab', 'id': 'tt0446686', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Dream Street', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Dream Street', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 1, 'month': 1, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0448304
# tvSeries
# Tanging yaman
# {'_id': '61e5851eb597b91eb9423813', 'id': 'tt0448304', 'primaryImage': {'id': 'rm1800596993', 'width': 670, 'height': 800, 'url': 'https://m.media-amazon.com/images/M/MV5BYmViOWRlMWMtYTBlYi00M2MxLTkwMDMtMTcwZTJkNDYwZDAxXkEyXkFqcGdeQXVyMjI4OTg3MTc@._V1_.jpg', 'caption': {'plainText': 'Tanging yaman (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'TV Series', 'id': 'tvSeries', 'isSeries': True, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Tanging yaman', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Tanging yaman', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 11, 'month': 1, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0451108
# movie
# Mad World
# {'_id': '61e58526971a4a15d64239e5', 'id': 'tt0451108', 'primaryImage': {'id': 'rm2809379584', 'width': 550, 'height': 712, 'url': 'https://m.media-amazon.com/images/M/MV5BMTEyOTk4NTQxNjReQTJeQWpwZ15BbWU3MDY5MzY0NzQ@._V1_.jpg', 'caption': {'plainText': 'Mad World (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Mad World', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Mad World', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 29, 'month': 8, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0454155
# movie
# El hada buena - Una fábula peronista
# {'_id': '61e5852fcffb8f2faa423aff', 'id': 'tt0454155', 'primaryImage': {'id': 'rm554840320', 'width': 980, 'height': 1400, 'url': 'https://m.media-amazon.com/images/M/MV5BNzJjN2FlNzctZmEzOS00OTMwLWEzMzItNTdiMTg3MzhjMTE1XkEyXkFqcGdeQXVyMTk0OTUyMw@@._V1_.jpg', 'caption': {'plainText': 'El hada buena - Una fábula peronista (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'El hada buena - Una fábula peronista', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'El hada buena - Una fábula peronista', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': 4, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0457591
# movie
# Memorias del desarrollo
# {'_id': '61e5853acffb8f2faa423dbf', 'id': 'tt0457591', 'primaryImage': {'id': 'rm3044776705', 'width': 4212, 'height': 6162, 'url': 'https://m.media-amazon.com/images/M/MV5BZjg4MTFkYjAtZGMzMi00MmEzLThjZmUtZTY5Yjk3MTZiZmQ0XkEyXkFqcGdeQXVyMTI1MTEzNw@@._V1_.jpg', 'caption': {'plainText': 'Memorias del desarrollo (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Memorias del desarrollo', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Memorias del desarrollo', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 26, 'month': 11, 'year': 2011, '__typename': 'ReleaseDate'}}
# tt0460778
# movie
# Drunkboat
# {'_id': '61e58542971a4a15d642406f', 'id': 'tt0460778', 'primaryImage': {'id': 'rm3633099264', 'width': 406, 'height': 586, 'url': 'https://m.media-amazon.com/images/M/MV5BMTMyMjU1OTgzOF5BMl5BanBnXkFtZTcwMTk4MzU5Ng@@._V1_.jpg', 'caption': {'plainText': 'Drunkboat (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Drunkboat', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Drunkboat', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 14, 'month': 6, 'year': 2013, '__typename': 'ReleaseDate'}}
# tt0463311
# movie
# Federal
# {'_id': '61e5854678c012aa34423ff7', 'id': 'tt0463311', 'primaryImage': {'id': 'rm305301248', 'width': 2400, 'height': 3500, 'url': 'https://m.media-amazon.com/images/M/MV5BMTkxOTUzMjIyNF5BMl5BanBnXkFtZTcwMjcyOTAxNA@@._V1_.jpg', 'caption': {'plainText': 'Federal (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Federal', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Federal', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 29, 'month': 10, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0465637
# movie
# Taken by Force
# {'_id': '61e5854d971a4a15d64242ad', 'id': 'tt0465637', 'primaryImage': {'id': 'rm2401410304', 'width': 432, 'height': 648, 'url': 'https://m.media-amazon.com/images/M/MV5BNzIyNTI3MDU4NF5BMl5BanBnXkFtZTcwNDY0NjAzMQ@@._V1_.jpg', 'caption': {'plainText': 'Taken by Force (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Taken by Force', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Taken by Force', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0465760
# movie
# Sensual
# {'_id': '61e58554e1a8ddbd964243c1', 'id': 'tt0465760', 'primaryImage': {'id': 'rm2228561920', 'width': 620, 'height': 369, 'url': 'https://m.media-amazon.com/images/M/MV5BNmFkNWFjOGMtZGFiNi00NWJmLTk0YzktYTU0NzUwOWEwM2Q0XkEyXkFqcGdeQXVyMjk2MzM1MTI@._V1_.jpg', 'caption': {'plainText': 'Sensual (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Sensual', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Sensual', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0469094
# movie
# Harlem Hostel
# {'_id': '61e585598a5a6a599f42462b', 'id': 'tt0469094', 'primaryImage': {'id': 'rm3695018753', 'width': 960, 'height': 1440, 'url': 'https://m.media-amazon.com/images/M/MV5BNmZhNDYxOWUtMDk1NS00MDNkLWJjOGUtMDA0OWVhMjhkYjAyXkEyXkFqcGdeQXVyNTI4NDM5MjI@._V1_.jpg', 'caption': {'plainText': 'Harlem Hostel (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Harlem Hostel', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Harlem Hostel', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 12, 'month': 2, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0473343
# movie
# Cielito lindo
# {'_id': '61e5855fef99b1c5434246a9', 'id': 'tt0473343', 'primaryImage': {'id': 'rm599622912', 'width': 2635, 'height': 4000, 'url': 'https://m.media-amazon.com/images/M/MV5BMTc3MzYyMDEzNV5BMl5BanBnXkFtZTcwNzUxMDMzNA@@._V1_.jpg', 'caption': {'plainText': 'Alejandro Alcondez in Cielito lindo (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Cielito lindo', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Cielito lindo', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 18, 'month': 6, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0475983
# movie
# The Deafening Silence of a Very Bright Light
# {'_id': '61e58570e1a8ddbd96424a39', 'id': 'tt0475983', 'primaryImage': {'id': 'rm2111554817', 'width': 1700, 'height': 1110, 'url': 'https://m.media-amazon.com/images/M/MV5BY2ZkMjMyMDQtMDAxMC00NjU1LWE2M2EtZGU5OWY3NjAwY2M4XkEyXkFqcGdeQXVyMjA5Mjk5OTM@._V1_.jpg', 'caption': {'plainText': 'Marie-Line Grinda in The Deafening Silence of a Very Bright Light (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'The Deafening Silence of a Very Bright Light', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'The Deafening Silence of a Very Bright Light', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': None}
# tt0479051
# movie
# The Greater Meaning of Water
# {'_id': '61e58572d735dff3f9424b69', 'id': 'tt0479051', 'primaryImage': {'id': 'rm1500155648', 'width': 450, 'height': 628, 'url': 'https://m.media-amazon.com/images/M/MV5BMjIwMTA3MzUwOV5BMl5BanBnXkFtZTcwNzI2MDgxMw@@._V1_.jpg', 'caption': {'plainText': 'The Greater Meaning of Water (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'The Greater Meaning of Water', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'The Greater Meaning of Water', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0482461
# movie
# Barry Munday
# {'_id': '61e5857d909c2ca781424d3f', 'id': 'tt0482461', 'primaryImage': {'id': 'rm4103503872', 'width': 1382, 'height': 2048, 'url': 'https://m.media-amazon.com/images/M/MV5BMTUzNTc4Nzg4N15BMl5BanBnXkFtZTcwMTM5NTE3Mw@@._V1_.jpg', 'caption': {'plainText': 'Judy Greer and Patrick Wilson in Barry Munday (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Barry Munday', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Barry Munday', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 13, 'month': 3, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0482459
# movie
# Bandeiji
# {'_id': '61e5857fcffb8f2faa424dbd', 'id': 'tt0482459', 'primaryImage': {'id': 'rm3652195328', 'width': 533, 'height': 750, 'url': 'https://m.media-amazon.com/images/M/MV5BZThkNGYwNjItMDkxZS00OTQ3LTg5ZDUtZDNkNTRiODBlOWE3XkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg', 'caption': {'plainText': 'Bandeiji (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Bandeiji', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Bandeiji', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 16, 'month': 1, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0483839
# movie
# A Woman Is a Woman
# {'_id': '61e58581d735dff3f9424ecd', 'id': 'tt0483839', 'primaryImage': {'id': 'rm3017091072', 'width': 999, 'height': 561, 'url': 'https://m.media-amazon.com/images/M/MV5BMGYwNDI3YzQtNjhmYi00ZDY4LWFkMGEtN2MwNDA4NTAxNGEzXkEyXkFqcGdeQXVyMjk2MzM1MTI@._V1_.jpg', 'caption': {'plainText': 'A Woman Is a Woman (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'A Woman Is a Woman', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'A Woman Is a Woman', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0490199
# movie
# PrimeMates
# {'_id': '61e58594d8f3c0931e425315', 'id': 'tt0490199', 'primaryImage': {'id': 'rm1969832960', 'width': 1200, 'height': 1728, 'url': 'https://m.media-amazon.com/images/M/MV5BMzM2M2U2OTAtODRlZC00ODYzLTk4ODktNWQxYWExNjM4OWY0XkEyXkFqcGdeQXVyNTQ3NTAwNzI@._V1_.jpg', 'caption': {'plainText': 'Will Wallace, Joe Estevez, Ethan Phillips, and Leo Rossi in PrimeMates (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'PrimeMates', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'PrimeMates', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 14, 'month': 1, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0493949
# movie
# Ramona and Beezus
# {'_id': '61e5859bcffb8f2faa425415', 'id': 'tt0493949', 'primaryImage': {'id': 'rm2236910848', 'width': 1374, 'height': 2048, 'url': 'https://m.media-amazon.com/images/M/MV5BMTk4MTU0MTczM15BMl5BanBnXkFtZTcwNjYzOTI0Mw@@._V1_.jpg', 'caption': {'plainText': 'Selena Gomez and Joey King in Ramona and Beezus (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Ramona and Beezus', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Ramona and Beezus', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 23, 'month': 7, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0494229
# movie
# Good Sharma
# {'_id': '61e5859d8a5a6a599f4255df', 'id': 'tt0494229', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Good Sharma', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Good Sharma', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2017, '__typename': 'ReleaseDate'}}
# tt0495037
# movie
# O Inimigo Sem Rosto
# {'_id': '61e585a1d8f3c0931e425609', 'id': 'tt0495037', 'primaryImage': {'id': 'rm2441798912', 'width': 320, 'height': 460, 'url': 'https://m.media-amazon.com/images/M/MV5BYTVmNTRiYTEtMmE0YS00NzE1LThiMWEtZTg0MGUwOGJhZGIwXkEyXkFqcGdeQXVyMjUyMTE3MTc@._V1_.jpg', 'caption': {'plainText': 'O Inimigo Sem Rosto (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'O Inimigo Sem Rosto', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'O Inimigo Sem Rosto', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 5, 'month': 8, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0499608
# movie
# Tranced
# {'_id': '61e585acb597b91eb9425935', 'id': 'tt0499608', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Tranced', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Tranced', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0515077
# tvEpisode
# Episode dated 28 November 2010
# {'_id': '61e585d9909c2ca781426211', 'id': 'tt0515077', 'primaryImage': None, 'titleType': {'text': 'TV Episode', 'id': 'tvEpisode', 'isSeries': False, 'isEpisode': True, '__typename': 'TitleType'}, 'titleText': {'text': 'Episode dated 28 November 2010', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Episode dated 28 November 2010', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 28, 'month': 11, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0758752
# movie
# Love & Other Drugs
# {'_id': '61e5889d8a5a6a599f43003d', 'id': 'tt0758752', 'primaryImage': {'id': 'rm1047036160', 'width': 1383, 'height': 2048, 'url': 'https://m.media-amazon.com/images/M/MV5BMTgxOTczODEyMF5BMl5BanBnXkFtZTcwMDc0NDY4Mw@@._V1_.jpg', 'caption': {'plainText': 'Anne Hathaway and Jake Gyllenhaal in Love & Other Drugs (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Love & Other Drugs', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Love & Other Drugs', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 6, 'month': 1, 'year': 2011, '__typename': 'ReleaseDate'}}
# tt0770778
# movie
# King of the Avenue
# {'_id': '61e588bbe1a8ddbd964305ff', 'id': 'tt0770778', 'primaryImage': {'id': 'rm4266755584', 'width': 366, 'height': 500, 'url': 'https://m.media-amazon.com/images/M/MV5BMjA3MjkzMjM3Ml5BMl5BanBnXkFtZTcwMDc2NTk5Mw@@._V1_.jpg', 'caption': {'plainText': 'King of the Avenue (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'King of the Avenue', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'King of the Avenue', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 17, 'month': 9, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0775543
# movie
# Night Catches Us
# {'_id': '61e588c678c012aa3443072d', 'id': 'tt0775543', 'primaryImage': {'id': 'rm1755152384', 'width': 1011, 'height': 1501, 'url': 'https://m.media-amazon.com/images/M/MV5BOTIyNDEyNjY3NF5BMl5BanBnXkFtZTcwNjY0MjE3Mw@@._V1_.jpg', 'caption': {'plainText': 'Kerry Washington and Anthony Mackie in Night Catches Us (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Night Catches Us', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Night Catches Us', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 3, 'month': 12, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0775489
# movie
# L'illusionniste
# {'_id': '61e588c6d735dff3f94308c7', 'id': 'tt0775489', 'primaryImage': {'id': 'rm784238336', 'width': 890, 'height': 1322, 'url': 'https://m.media-amazon.com/images/M/MV5BMTg0MjI4MTcxMF5BMl5BanBnXkFtZTcwNTQ1ODUwNA@@._V1_.jpg', 'caption': {'plainText': "L'illusionniste (2010)", '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': "L'illusionniste", '__typename': 'TitleText'}, 'originalTitleText': {'text': "L'illusionniste", '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 22, 'month': 7, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0774519
# movie
# El cielo elegido
# {'_id': '61e588c7d8f3c0931e430921', 'id': 'tt0774519', 'primaryImage': {'id': 'rm3737289728', 'width': 2244, 'height': 3242, 'url': 'https://m.media-amazon.com/images/M/MV5BMjIxMjM1ODUxNF5BMl5BanBnXkFtZTcwNjQ0ODQxNA@@._V1_.jpg', 'caption': {'plainText': 'El cielo elegido (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'El cielo elegido', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'El cielo elegido', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 20, 'month': 9, 'year': 2012, '__typename': 'ReleaseDate'}}
# tt0780653
# movie
# The Wolfman
# {'_id': '61e588d6e1a8ddbd96430c1b', 'id': 'tt0780653', 'primaryImage': {'id': 'rm483692032', 'width': 510, 'height': 755, 'url': 'https://m.media-amazon.com/images/M/MV5BOTUyODEyMDIyM15BMl5BanBnXkFtZTcwNTYxMzg5Mg@@._V1_.jpg', 'caption': {'plainText': 'US one-sheet', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'The Wolfman', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'The Wolfman', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 11, 'month': 2, 'year': 2010, '__typename': 'ReleaseDate'}}
# tt0790663
# movie
# The First Grader
# {'_id': '61e588ecef99b1c5434311a1', 'id': 'tt0790663', 'primaryImage': {'id': 'rm3820599552', 'width': 1376, 'height': 2048, 'url': 'https://m.media-amazon.com/images/M/MV5BMTUxNzQ3NTE5M15BMl5BanBnXkFtZTcwNTgxNTEyNQ@@._V1_.jpg', 'caption': {'plainText': 'Justin Chadwick, Naomie Harris, Oliver Litondo, Ann Peacock, David M. Thompson, and Sam Feuer in The First Grader (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'The First Grader', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'The First Grader', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 18, 'month': 8, 'year': 2011, '__typename': 'ReleaseDate'}}
# tt0798817
# movie
# 13
# {'_id': '61e58907d8f3c0931e431809', 'id': 'tt0798817', 'primaryImage': {'id': 'rm4090305792', 'width': 1047, 'height': 1500, 'url': 'https://m.media-amazon.com/images/M/MV5BOWE4YWZjYWItY2U0NS00N2ZlLWFkOGEtY2M2N2E0NDA5MjBlXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_.jpg', 'caption': {'plainText': 'Mickey Rourke, Jason Statham, Sam Riley, and 50 Cent in 13 (2010)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': '13', '__typename': 'TitleText'}, 'originalTitleText': {'text': '13', '__typename': 'TitleText'}, 'releaseYear': {'year': 2010, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 16, 'month': 6, 'year': 2011, '__typename': 'ReleaseDate'}}
