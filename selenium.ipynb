# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %%
# Inicializa el navegador Chrome
driver = webdriver.Chrome()

# Navega a la página web "http://www.imdb.com"
driver.get("http://www.imdb.com")

# Maximizar la ventana del navegador
driver.maximize_window()

# Acepta las cookies haciendo clic en el elemento con el selector CSS
driver.find_element("css selector", "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd").click()

sleep(5)

# Entra al Menú haciendo click en el elemento selector de CSS
driver.find_element("css selector", "#imdbHeader-navDrawerOpen > svg").click()

sleep(5)

# Entra a buscar entre series y peliculas

driver.find_element("css selector", "#imdbHeader > div.ipc-page-content-container.ipc-page-content-container--center.navbar__inner > aside.sc-carGes.bVsgci.drawer.hamburger__drawer.imdb-header__nav-drawer > div > div.drawer__panelContent > div > div:nth-child(1) > span > div > div > ul > a:nth-child(4) > span").click()

# Realizar un scroll hacia abajo en la página web para visualizar el buscador de películas por género
sleep(5)
driver.execute_script("window.scrollTo(0,500)")

sleep(5)

# Entra a buscar películas por género
driver.find_element("css selector", "#__next > main > div > section > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(3) > div.ipc-chip-list--base.ipc-chip-list.ipc-chip-list--wrap.sc-7e857967-1.exgdzz > div.ipc-chip-list__scroller > a:nth-child(1)").click()

sleep(7)

# Crear una lista vacía para almacenar las URLs de películas
lista_url = []

# Iterar 5 películas
for i in range(1, 6 ):
    # En cada iteración, obtener la URL de la película y agregarla a la lista
    lista_url.append(driver.find_element("xpath", f'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li[{i}]/div/div/div/div[1]/div[2]/div[1]/a').get_attribute("href"))
print(lista_url)

sleep(6)

driver.execute_script("window.scrollTo(0,400)")

diccionario_peliculas = {
    "Nombre": [],
    "Argumento": [],
    "Direccion": [],
    "Guionistas": [],
    "Duracion" : [],
    "Puntuacion" :[] }

sleep(6)
# Iterar a través de las URL en la lista_url.

for i in range(1, 6):
    driver.find_element("css selector", f'#__next > main > div.ipc-page-content-container.ipc-page-content-container--center.sc-dec63aac-0.uHlFE > div.ipc-page-content-container.ipc-page-content-container--center > section > section > div > section > section > div:nth-child(2) > div > section > div.ipc-page-grid.ipc-page-grid--bias-left.ipc-page-grid__item.ipc-page-grid__item--span-2 > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > ul > li:nth-child(1) > div > div > div > div.sc-74bf520e-2.cVXqoq > div.sc-b189961a-0.hBZnfJ > div.ipc-title.ipc-title--base.ipc-title--title.ipc-title-link-no-icon.ipc-title--on-textPrimary.sc-b189961a-9.iALATN.dli-title > a').click()
    sleep(3)
    driver.execute_script("window.scrollTo(0,500)")                                       
diccionario_peliculas["Nombre"].append(driver.find_element("css selector", '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.fSJiHR > section > div:nth-child(5) > section > section > div.sc-92625f35-4.iDcoFI > div.sc-92625f35-6.gHKhNg > div.sc-92625f35-10.dwKwMe > section > p > span.sc-7193fc79-0.ftEVcu').text)                                           
print(diccionario_peliculas)
sleep(3)
# Cierra el navegador
#driver.close()
# Out:
# ['https://www.imdb.com/title/tt1684562/?ref_=sr_t_1', 'https://www.imdb.com/title/tt17279496/?ref_=sr_t_2', 'https://www.imdb.com/title/tt15239678/?ref_=sr_t_3', 'https://www.imdb.com/title/tt19637052/?ref_=sr_t_4', 'https://www.imdb.com/title/tt11389872/?ref_=sr_t_5']
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[10], line 60
#      57 # Iterar a través de las URL en la lista_url.
#      59 for i in range(1, 6):
# ...

# %% [markdown]
# diccionario_peliculas = {
#     "Nombre": [],
#     "Argumento": [],
#     "Direccion": [],
#     "Guionistas": [],
#     "Duracion" : [],
#     "Puntuacion" :[] }
#
#
# # Iterar a través de las URL en la lista_url.
#
# for i in lista_url:
#     driver.find_element("css selector", f"#__next > main > div.ipc-page-content-container.ipc-page-content-container--center.sc-dec63aac-0.uHlFE > div.ipc-page-content-container.ipc-page-content-container--center > section > section > div > section > section > div:nth-child(2) > div > section > div.ipc-page-grid.ipc-page-grid--bias-left.ipc-page-grid__item.ipc-page-grid__item--span-2 > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > ul > li:nth-child(1) > div > div > div > div.sc-ab6fa25a-2.gOsifL > div.sc-b189961a-0.hBZnfJ > div.ipc-title.ipc-title--base.ipc-title--title.ipc-title-link-no-icon.ipc-title--on-textPrimary.sc-b189961a-9.iALATN.dli-title > a").click()
#
#     sleep(3)
#
#     # Extraer el nombre de la película y agregarlo al diccionario.
#     #diccionario_peliculas["Nombre"].append(driver.find_element("css selector", f'#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.fSJiHR > section > div:nth-child(5) > section > section > div.sc-4e4cc5f9-3.dDRspk > div.sc-b7c53eda-0.dUpRPQ > h1').text)
#
#
#     # Extraer el argumento de la película y agregarlo al diccionario.
#     #diccionario_peliculas["Argumento"].append(sopa_imbd.find("span", {"class": "span.sc-a31b0662-0.iBnSmy"}).text)
#
#     # Extraer la dirección de la película y agregarlo al diccionario.
#     #diccionario_peliculas["Direccion"].append(sopa_imbd.find("span", {"class": ""}).text)
#
#     # Extraer el/la/los guionistas y agregarlo/a/s al diccionario.
#     #diccionario_peliculas["Guionistas"].append(sopa_imbd.find("span", {"class": ""}).text)
#
#     # Extraer la duración (en minutos) de la película y agregarlo al diccionario.
#     #diccionario_peliculas["Duracion"].append(sopa_imbd.find("span", {"class": ""}).text)
#
#     # Extraer la puntuación (en caso de tenerla) de la película y agregarlo al diccionario.
#     #diccionario_peliculas["Puntuacion"].append(sopa_imbd.find("span", {"class": ""}).text)

# %% [markdown]
# #diccionario_peliculas.text
# #for url in lista_url:
#     # Hacer una solicitud GET a la URL especificada.
#
#     #headers = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Mobile Safari/537.36'}
#     #url = "https://www.imdb.com/feature/genre/?ref_=nv_ch_gr"
#     #res_imbd = requests.get(url,headers=headers)
#     #print(res_imbd.status_code)
